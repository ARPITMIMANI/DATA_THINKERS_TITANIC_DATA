# %%
import pandas as pd

# LOAD THE "TITANIC_DATA.xlsx" DATA SET .

df = pd.read_excel("TITANIC_DATA.xlsx")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
"THE SHAPE OF THE DATA SET IS :" , df.shape
# Out:
# ('THE SHAPE OF THE DATA SET IS :', (891, 12))

# %%
"THE NUMBER OF ROWS IN THE DATA SET IS :" , df.shape[0]
# Out:
# ('THE NUMBER OF ROWS IN THE DATA SET IS :', 891)

# %%
"THE NUMBER OF COLUMNS IN THE DATA SET IS :" , df.shape[1]
# Out:
# ('THE NUMBER OF COLUMNS IN THE DATA SET IS :', 12)

# %%
# FIND THE TOP 10 ROWS OF THE DATA SET .

df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# FIND THE TOP 10 ROWS OF THE DATA SET .

df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
"THE INFORMATION OF THE DATA SET IS GIVEN ABOVE" , df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# ('THE INFORMATION OF THE DATA SET IS GIVEN ABOVE', None)

# %%
# FIND THE OVERALL STATISTICS OF THE DATA SET .

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# FIND THE OVERALL STATISTICS OF ALL THE COLUMNS OF THE DATA SET .

df.describe ( include="all" )
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
# DISPLAY THE LIST OF COLUMNS OF THE DATA SET .

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# DISPLAY THE "Name" COLUMN ONLY .

df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# DISPLAY THE "Name" AND "Age" COLUMN ONLY .

df [[ "Name" , "Age" ]]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
# FILTER THE COLUMN "Sex" WITH "male" ONLY .

df [ df["Sex"] == "male" ]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df["Sex"] == "male"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
# FIND THE NUMBER OF "male" FROM THE COLUMN "Sex" .

sum ( df["Sex"] == "male" )
# Out:
# 577

# %%
# FIND THE NUMBER OF "female" FROM THE COLUMN "Sex" .

sum ( df["Sex"] == "female" )
# Out:
# 314

# %%
# FILTER THE COLUMN "Sex" WITH "male" AND DISPLAY TOP 6 ROWS .

df [ df["Sex"] == "male" ] .head(6)
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 5             6         0       3                Moran, Mr. James  male   NaN
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7             8         0       3  Palsson, Master. Gosta Leonard  male   2.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked
# 0       1      0  A/5 21171   7.2500   NaN        S
# 4       0      0     373450   8.0500   NaN        S
# 5       0      0     330877   8.4583   NaN        Q
# 6       0      0      17463  51.8625   E46        S
# 7       3      1     349909  21.0750   NaN        S
# 12      0      0  A/5. 2151   8.0500   NaN        S

# %%
# DISPLAY THE LIST OF COLUMNS OF THE DATA SET .

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# FILTER THE COLUMN "Survived" WITH 1.0 ONLY .

df [ df["Survived"] == 1 ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# FIND THE NUMBER OF 1.0 FROM THE COLUMN "Survived" .

sum ( df["Survived"] == 1 )
# Out:
# 342

# %%
# CHECK NULL VALUES IN THE DATA SET .

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# PLOT THE HEAT MAP OF THE NULL VALUES .

import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap ( data=df.isnull() )
# Out:
# <Axes: >

# %%
# FIND THE PERCENTAGE OF NULL VALUES .

null_percentage = df.isnull().sum() / len(df) * 100
null_percentage
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
# DROP THE COLUMN "Cabin" FROM THE DATA SET PERMANENTLY .

df.drop ( "Cabin" , axis=1 , inplace=True )
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# CHECK NULL VALUES IN THE DATA SET .

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
# DISPLAY THE LIST OF COLUMNS OF THE DATA SET .

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
# DISPLAY THE UNIQUE VALUES OF "Embarked" COLUMN .

df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
# DISPLAY THE "Embarked" COLUMN ONLY .

df["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
# FIND THE MOST FREQUENT VALUE OF THE COLUMN "Embarked" .

df["Embarked"].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
# HANDLE THE MISSING VALUES OF COLUMN "Embarked" PERMANENTLY .

df["Embarked"].fillna ( "S" , inplace=True )
df["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
# CHECK NULL VALUES IN THE DATA SET .

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
# DISPLAY THE "Age" COLUMN ONLY .

df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# FIND THE AVERAGE OF THE COLUMN "Age" .

df["Age"].mean()
# Out:
# 29.69911764705882

# %%
# HANDLE THE MISSING VALUES OF COLUMN "Age" PERMANENTLY .

df["Age"].fillna ( df["Age"].mean() , inplace=True )
df["Age"]
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
# CHECK NULL VALUES IN THE DATA SET .

df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# DDIPLAY THE UNIQUE VALUES OF "Sex" COLUMN .

df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# ENCODE DATA OF COLUMN "Sex" USING map() .

df["Gender"] = df["Sex"].map ({ "male":1 , "female":0 })
df["Gender"]
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Gender, Length: 891, dtype: int64

# %%
# CHECKING THE NEW COLUMN "Gender" .

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Gender
# 0      0         A/5 21171   7.2500        S       1
# 1      0          PC 17599  71.2833        C       0
# 2      0  STON/O2. 3101282   7.9250        S       0
# 3      0            113803  53.1000        S       0
# ...

# %%
# INSERT THE NEW COLUMN "GenderNew" AFTER COLUMN "Sex" AND CHECK THE NEW COLUMN .

gn = df["Sex"].map ({ "male":1 , "female":0 })
df.insert ( 5 , "GenderNew" , gn )
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  GenderNew   Age  \
# 0                            Braund, Mr. Owen Harris    male          1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female          0  38.0
# 2                             Heikkinen, Miss. Laina  female          0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female          0  35.0
# 4                           Allen, Mr. William Henry    male          1  35.0
#
#    SibSp  Parch            Ticket     Fare Embarked  Gender
# 0      1      0         A/5 21171   7.2500        S       1
# 1      1      0          PC 17599  71.2833        C       0
# 2      0      0  STON/O2. 3101282   7.9250        S       0
# ...

# %%
# DISPLAY THE UNIQUE VALUES OF "Embarked" COLUMN .

df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
# FIND THE NUMBER OF UNIQUE VALUES OF "Embarked" COLUMN .

df["Embarked"].nunique()
# Out:
# 3

# %%
# ENCODE DATA OF COLUMN "Embarked" USING get_dummies() .

em = pd.get_dummies ( data=df , columns=["Embarked"] )
em

# pd.get_dummies ( data=df , columns=["Embarked"] , drop_first=True )
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  GenderNew  \
# 0                              Braund, Mr. Owen Harris    male          1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female          0
# 2                               Heikkinen, Miss. Laina  female          0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female          0
# 4                             Allen, Mr. William Henry    male          1
# ..                                                 ...     ...        ...
# ...

# %%
# DISPLAY THE LIST OF COLUMNS OF THE DATA SET .

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'GenderNew', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
# FIND THE NUMBER OF PEOPLE FROM THE COLUMN "Survived" .

df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# DISPLAY THE LIST OF COLUMNS OF THE DATA SET .

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'GenderNew', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
# DISPLAY THE UNIQUE VALUES OF "Pclass" COLUMN .

df["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
# FIND THE NUMBER OF PEOPLE OF " FIRST CLASS , SECOND CLASS , THIRD CLASS " FROM THE COLUMN "Pclass" .

df["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# FIND THE NUMBER OF PEOPLE OF " male , female " FROM THE COLUMN "Sex" .

df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# PLOT THE HISTOGRAM FOR THE COLUMN "Age" .

import seaborn as sns
import matplotlib.pyplot as plt
plt.hist ( df["Age"] )
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.hist ( x=df["Age"] )
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
# PLOT THE BOX PLOT  FOR THE COLUMN "Age" .

import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot ( data=df["Age"] )
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot ( data=df["Age"] , orient="h" )
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot ( data=df["Age"] , orient="v" )
# Out:
# <Axes: >

# %%
# DISPLAY THE LIST OF COLUMNS OF THE DATA SET .

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'GenderNew', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
# FIND HOW HAS BETTER CHANCE OF SURVIVAL : MALE OR FEMALE .

sns.barplot ( x="Sex" , y="Survived" , data=df )
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
# FIND HOW HAS BETTER CHANCE OF SURVIVAL : FIRST CLASS , SECOND CLASS OR THIRD CLASS .

sns.barplot ( x="Pclass" , y="Survived" , data=df )
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
# DISPLAY THE LIST OF COLUMNS OF THE DATA SET .

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'GenderNew', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
# CREATE A NEW COLUMN "FamilySize" BY ADDING COLUMNS "SibSp" , "Parch" TOGETHER AND CHECK THE NEW COLUMN .

df["FamilySize"] = df["SibSp"] + df["Parch"]
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  GenderNew   Age  \
# 0                            Braund, Mr. Owen Harris    male          1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female          0  38.0
# 2                             Heikkinen, Miss. Laina  female          0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female          0  35.0
# 4                           Allen, Mr. William Henry    male          1  35.0
#
#    SibSp  Parch            Ticket     Fare Embarked  Gender  FamilySize
# 0      1      0         A/5 21171   7.2500        S       1           1
# 1      1      0          PC 17599  71.2833        C       0           1
# 2      0      0  STON/O2. 3101282   7.9250        S       0           0
# ...

# %%
# FIND THE FARE OF PER PERSON .

df["FarePerPerson"] = df["Fare"] / ( df["FamilySize"] + 1 )
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  GenderNew  \
# 0                            Braund, Mr. Owen Harris    male          1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female          0
# 2                             Heikkinen, Miss. Laina  female          0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female          0
# 4                           Allen, Mr. William Henry    male          1
# 5                                   Moran, Mr. James    male          1
# 6                            McCarthy, Mr. Timothy J    male          1
# ...
